# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ## Introduction

# %% [markdown]
# ## Objectives
#
# In this notebook we will have an overview of what has been covered in the tools for Data science science module.
# In this notebook We will cover :
#
# - ___some of the popular languages used in data Science___.
# - ___Libraries used in the data Sciencce field___.
# - ___Data Science tools___.
# - ___A glance at arithmetics operations in python___.

# %% [markdown]
# In this module, we have covered some popular languages used by data scientits such as:
# - Apache MLlib
# - C++
# - Python
# - R
# - Julia
# - JavaScript
# - SQL

# %% [markdown]
# ### Data SCience Libraries
#
# We also covered some populare libraries used in the field:
#
# * Pandas
# * NumPy
# * TensorFlow
# * ggplot
# * Scikit-learn

# %% [markdown]
# ### Data Science Tools
#
# We also browsed some of the popular used tools in data science :
#
# | Data Science |
# |--------------|
# | IBM's Watson Sudio |
# | RStudio |
# | Git |
# | Jupyter Notebook |

# %% [markdown]
# ### Arithmetic Expression in python
#
# Here are few examples of arithmetics operations :

# %%
# Below we initiate a variable z with some basics arithmetic operationss.
# Python respects mathematics BODMAS rules. In this case the expression in 
# parenthesis will first be executed and added to the expression on the right

z = (3 * 4) +5
z
# Out:
# 17

# %%
# Another example with division

minutes = 200
hours = minutes / 60
print(f"{minutes} minutes is {hours} hours")
# Out:
# 200 minutes is 3.3333333333333335 hours

# %% [markdown]
# ## Author
#
# Olivier KABEYA MATANDA
